# %%
import csv

# %%
import pandas as pd

# %%
import numpy as np

# %%
a = "~/Documents/GitHub/CampaignDonations/Code/walt_disney_PANELMODEL.csv"
df = pd.read_csv(a)

df["Donation_Change"] = 0

for x in range(len(df)):
    df["Donation_Change"].iloc[x] = df["donations_dollars_lag"].iloc[x] - df["donations_dollars"].iloc[x]

df.head()
# Out:
# /Users/georg/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#   party_short  donations_dollars  partyline_percent  donations_dollars_lag  \
# 0           D                0.0           0.000000                    0.0
# 1           D                0.0           0.333333                    0.0
# 2           D                0.0           0.400000                 1000.0
# 3           D             1000.0           1.000000                    NaN
# 4           D                0.0           0.500000                 2000.0
#
#    data_use MODELING_GROUP  democrat  Donation_Change
# 0     0.727        TESTING         1              0.0
# ...

# %%
b = "~/Documents/GitHub/CampaignDonations/Code/walt_data_long.csv"
df2 = pd.read_csv(b)

df2.head()
# Out:
#    person  Year party_short  donations_dollars  partyline_percent
# 0       4  2012           D                0.0               0.00
# 1      10  2012           D                0.0               0.50
# 2      12  2012           D                0.0               0.25
# 3      14  2012           D                0.0               0.25
# 4      15  2012           D                0.0               0.00

# %%
df2["donation_change"] = 0


for x in range(len(df)):
    if df2["Year"].iloc[x] == 2012:
        df2["donation_change"].iloc[x] = df2["donations_dollars"].iloc[x] - df2["donations_dollars"].iloc[x]
        
for x in range(len(df)):
    df3 = df2[df2["person"]== x]
    
        df2["donation_change"].iloc[x] = df2["donations_dollars"].iloc[x] - df2["donations_dollars"].iloc[x]
        
        
    
    > df_First["donations2014"].iloc[x]:  
        df_First["Donation_Change"].iloc[x] = 0 
    if df_First["donations2012"].iloc[x] < df_First["donations2014"].iloc[x]:  
        df_First["Donation_Change"].iloc[x] = 2
