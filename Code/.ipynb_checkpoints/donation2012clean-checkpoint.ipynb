# %%
import pandas as pd
import numpy as np
# %cd C:\Users\jmitc\rollcall\Donation_Data
# Out:
# C:\Users\jmitc\rollcall\Donation_Data

# %%
donations_2012 = pd.read_csv('donations2012.csv')
donations_2012.head()
# Out:
#          Recipient   Total From Individuals From PACs      Recipient Type  \
# 0  Berman Howard L  $38750           $28750    $10000  Candidate (D-CA28)
# 1    Baldwin Tammy  $12500           $12500        $0  Candidate (D-WI02)
# 2   Webster Daniel  $12000            $6750     $5250  Candidate (R-FL08)
# 3      Schiff Adam  $10500             $500    $10000  Candidate (D-CA29)
# 4       Barton Joe  $10000            $8000     $2000  Candidate (R-TX06)
#
#          View  Type Chamber
# 0    Democrat  Cand   House
# 1    Democrat  Cand   House
# 2  Republican  Cand   House
# 3    Democrat  Cand   House
# 4  Republican  Cand   House

# %%
def keep_columns(df):
    df = df[['Recipient', 'Total', 'View']]
    return df

# %%
donations_2012 = keep_columns(donations_2012)
donations_2012.head()
# Out:
#          Recipient   Total        View
# 0  Berman Howard L  $38750    Democrat
# 1    Baldwin Tammy  $12500    Democrat
# 2   Webster Daniel  $12000  Republican
# 3      Schiff Adam  $10500    Democrat
# 4       Barton Joe  $10000  Republican

# %%
def strip_money(df):
    stripped_money = df['Total'].str.replace('$', '')
    df['Total'] = stripped_money.astype('float')
    return df

# %%
donations2012 = strip_money(donations_2012)

# %%
donations2012.head()
# Out:
#          Recipient    Total        View
# 0  Berman Howard L  38750.0    Democrat
# 1    Baldwin Tammy  12500.0    Democrat
# 2   Webster Daniel  12000.0  Republican
# 3      Schiff Adam  10500.0    Democrat
# 4       Barton Joe  10000.0  Republican

# %%
# new data frame with split value columns
data_names = donations2012["Recipient"].str.split(" ", n = 0, expand = True).copy()

# %%
frames = [donations2012, data_names]
donations2012 = pd.concat(frames, axis = 1)

# %%
donations2012.head(10)
# Out:
#          Recipient    Total        View        0        1     2
# 0  Berman Howard L  38750.0    Democrat   Berman   Howard     L
# 1    Baldwin Tammy  12500.0    Democrat  Baldwin    Tammy  None
# 2   Webster Daniel  12000.0  Republican  Webster   Daniel  None
# 3      Schiff Adam  10500.0    Democrat   Schiff     Adam  None
# 4       Barton Joe  10000.0  Republican   Barton      Joe  None
# 5  Sanchez Loretta   9000.0    Democrat  Sanchez  Loretta  None
# 6   Becerra Xavier   8100.0    Democrat  Becerra   Xavier  None
# 7   Bono Mack Mary   7000.0  Republican     Bono     Mack  Mary
# 8     Waxman Henry   7000.0    Democrat   Waxman    Henry  None
# 9       Upton Fred   6500.0  Republican    Upton     Fred  None

# %%
# Dropping old Name columns
donations2012 = donations2012.drop(columns =["Recipient"])

# %%
donations2012.head()
# Out:
#      Total        View        0       1     2
# 0  38750.0    Democrat   Berman  Howard     L
# 1  12500.0    Democrat  Baldwin   Tammy  None
# 2  12000.0  Republican  Webster  Daniel  None
# 3  10500.0    Democrat   Schiff    Adam  None
# 4  10000.0  Republican   Barton     Joe  None

# %%
donations2012.isnull().sum(axis = 0)
# Out:
# Total      0
# View       0
# 0          0
# 1          0
# 2        113
# dtype: int64

# %%
donations2012 = donations2012.drop(columns =[2])

# %%
donations2012.head()
# Out:
#      Total        View        0       1
# 0  38750.0    Democrat   Berman  Howard
# 1  12500.0    Democrat  Baldwin   Tammy
# 2  12000.0  Republican  Webster  Daniel
# 3  10500.0    Democrat   Schiff    Adam
# 4  10000.0  Republican   Barton     Joe

# %%
donations2012.iloc[:, ::-1]
# Out:
#            1         0        View    Total
# 0     Howard    Berman    Democrat  38750.0
# 1      Tammy   Baldwin    Democrat  12500.0
# 2     Daniel   Webster  Republican  12000.0
# 3       Adam    Schiff    Democrat  10500.0
# 4        Joe    Barton  Republican  10000.0
# ..       ...       ...         ...      ...
# 134   Hakeem  Jeffries    Democrat    250.0
# 135   Julius  Melendez  Republican    250.0
# 136  Charles    Rangel    Democrat    200.0
# 137   Gloria    McLeod    Democrat    200.0
# 138  Darrell      Issa  Republican    200.0
#
# [139 rows x 4 columns]

# %%
donations2012['First Name'] = donations2012[1]
donations2012['Last Name'] = donations2012[0]
donations2012['donations2012'] = donations2012['Total']
donations2012['Party'] = donations2012['View']

# %%
donations2012.head()
# Out:
#      Total        View        0       1 First Name Last Name  donations2012  \
# 0  38750.0    Democrat   Berman  Howard     Howard    Berman        38750.0
# 1  12500.0    Democrat  Baldwin   Tammy      Tammy   Baldwin        12500.0
# 2  12000.0  Republican  Webster  Daniel     Daniel   Webster        12000.0
# 3  10500.0    Democrat   Schiff    Adam       Adam    Schiff        10500.0
# 4  10000.0  Republican   Barton     Joe        Joe    Barton        10000.0
#
#         Party
# 0    Democrat
# 1    Democrat
# 2  Republican
# 3    Democrat
# 4  Republican

# %%
donations2012 = donations2012.drop(columns =['Total'])
donations2012 = donations2012.drop(columns =['View'])
donations2012 = donations2012.drop(columns =[0])
donations2012 = donations2012.drop(columns =[1])

# %%
donations2012.head()
# Out:
#   First Name Last Name  donations2012       Party
# 0     Howard    Berman        38750.0    Democrat
# 1      Tammy   Baldwin        12500.0    Democrat
# 2     Daniel   Webster        12000.0  Republican
# 3       Adam    Schiff        10500.0    Democrat
# 4        Joe    Barton        10000.0  Republican

# %%
len(donations2012)
# Out:
# 139

# %%
def clean_names(df):
    # new data frame with split value columns
    data_names = df["Recipient"].str.split(" ", n = 0, expand = True).copy()
    frames = [df, data_names]
    df = pd.concat(frames, axis = 1)
    df['First Name'] = df[1]
    df['Last Name'] = df[0]
    df['donations2012'] = df['Total']
    df['Party'] = df['View']  
    df = df.drop(columns =['Total'])
    df = df.drop(columns =['View'])
    df = df.drop(columns =[0])
    df = df.drop(columns =[1])
    df = df.drop(columns =[2])
    df = df.drop(columns =["Recipient"])
    df.iloc[:, ::-1]
    return df

# %%
test = pd.read_csv('donations2012.csv')

# %%
clean1 = keep_columns(test)

# %%
clean1.head()
# Out:
#          Recipient   Total        View
# 0  Berman Howard L  $38750    Democrat
# 1    Baldwin Tammy  $12500    Democrat
# 2   Webster Daniel  $12000  Republican
# 3      Schiff Adam  $10500    Democrat
# 4       Barton Joe  $10000  Republican

# %%
clean2 = strip_money(clean1)
# Out:
# <ipython-input-5-089944ab8ae0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = stripped_money.astype('float')

# %%
clean2.head()
# Out:
#          Recipient    Total        View
# 0  Berman Howard L  38750.0    Democrat
# 1    Baldwin Tammy  12500.0    Democrat
# 2   Webster Daniel  12000.0  Republican
# 3      Schiff Adam  10500.0    Democrat
# 4       Barton Joe  10000.0  Republican

# %%
clean3 = clean_names(clean2)

# %%
clean3.head()
# Out:
#   First Name Last Name  donations2012       Party
# 0     Howard    Berman        38750.0    Democrat
# 1      Tammy   Baldwin        12500.0    Democrat
# 2     Daniel   Webster        12000.0  Republican
# 3       Adam    Schiff        10500.0    Democrat
# 4        Joe    Barton        10000.0  Republican
