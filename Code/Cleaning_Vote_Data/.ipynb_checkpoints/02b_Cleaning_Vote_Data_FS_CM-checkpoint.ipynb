# %%
import csv
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#  Vote_Results_FinancialSector_Commodities_Markets_GovTrack = FS_CM

# %%
# Definition of Functions 

def my_function(link, bill): 
  a = "~/Documents/GitHub/CampaignDonations/External_Input_Data/Voting_Data/Vote_Results_FinancialSector_Commodities_Markets_GovTrack/" + link
  df = pd.read_csv(a)
  df_Democratic = df[df["party"] == "Democrat"]
  df_Republican = df[df["party"] == "Republican"]
  df_Democratic["D_MajorityVote"] = df_Democratic["vote"].max()
  df_Republican["R_MajorityVote"] = df_Republican["vote"].max()
  # Getting Dummy for voting along party-line
  # As our main independet variable is a percetage of votes along party line, all independent candidates are dropped 
  df_Democratic["VoteAlongPartyLine"] = 0
  df_Republican["VoteAlongPartyLine"] = 0
  for x in range(len(df_Democratic)):
    if df_Democratic["vote"].iloc[x] == df_Democratic["D_MajorityVote"].iloc[x]:
     df_Democratic["VoteAlongPartyLine"].iloc[x] = 1
  for x in range(len(df_Republican)):
    if df_Republican["vote"].iloc[x] == df_Republican["R_MajorityVote"].iloc[x]: 
     df_Republican["VoteAlongPartyLine"].iloc[x] = 1

  # Merge both party-specific datasets into one 
  # First: drop party-specific columns 
  df_Democratic = df_Democratic.drop(columns = ["D_MajorityVote"])
  df_Republican = df_Republican.drop(columns = ["R_MajorityVote"])
  # Bind them back together
  df = df_Democratic.append(df_Republican)
  b = "VoteAlong" + bill
  df.columns = df.columns.str.replace('VoteAlongPartyLine', b)
  return(df)

# This Function returns a list with all unique MoH that votes at least once in the timeframe observed
def Unique_MoHs_function(MoH): 
    MoH = MoH.drop_duplicates()
    MoH = pd.DataFrame(MoH)
    MoH.columns = ['person', 'name']
    Unique_MoHs = MoH
    return(Unique_MoHs)

# %%
# 113th Congress 

df1 = my_function("113th/congress_votes_113-2013_h215.csv", "1")
a1 = df1[["person", "name"]] 
b1 = df1.drop(columns = ["state", "district", "vote",  "name", "party"])


df2 = my_function("113th/congress_votes_113-2013_h216.csv", "2")
a2 = df2[["person", "name"]] 
b2 = df2.drop(columns = ["state", "district", "vote",  "name", "party"])


df3 = my_function("113th/congress_votes_113-2013_h218.csv", "3")
a3 = df3[["person", "name"]] 
b3 = df3.drop(columns = ["state", "district", "vote",  "name", "party"])

df4 = my_function("113th/congress_votes_113-2013_h219.csv", "4")
a4 = df4[["person", "name"]] 
b4 = df4.drop(columns = ["state", "district", "vote",  "name", "party"])

df5 = my_function("113th/congress_votes_113-2014_h349.csv", "5")
a5 = df5[["person", "name"]] 
b5 = df5.drop(columns = ["state", "district", "vote",  "name", "party"])

df6 = my_function("113th/congress_votes_113-2014_h501.csv", "6")
a6 = df6[["person", "name"]] 
b6 = df6.drop(columns = ["state", "district", "vote",  "name", "party"])

df7 = my_function("113th/congress_votes_113-2014_h557.csv", "7")
a7 = df7[["person", "name"]] 
b7 = df7.drop(columns = ["state", "district", "vote",  "name", "party"])


List_MoHs = a1.append(a2.append(a3.append(a4.append(a5.append(a6.append(a7))))))
Unique_MoHs = Unique_MoHs_function(List_MoHs)


All_MoHs_Merge = pd.merge(Unique_MoHs , b1, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b2, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b3, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b4, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b5, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b6, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b7, how='left')


All_MoHs_Merge["VoteAlong113thRatio_FS_CM"] = All_MoHs_Merge["VoteAlong1"]  + All_MoHs_Merge["VoteAlong2"] + All_MoHs_Merge["VoteAlong3"]  + All_MoHs_Merge["VoteAlong4"]  +  All_MoHs_Merge["VoteAlong5"] +  All_MoHs_Merge["VoteAlong6"] +  All_MoHs_Merge["VoteAlong7"]

All_MoHs_Merge["VoteAlong113thRatio_FS_CM"] = All_MoHs_Merge["VoteAlong113thRatio_FS_CM"]/7

All_MoHs_Merge_113th_FS_CM = All_MoHs_Merge


list = ["VoteAlong1", "VoteAlong2", "VoteAlong3", "VoteAlong4", "VoteAlong5", "VoteAlong6", "VoteAlong7" ]
All_MoHs_Merge_113th_FS_CM =  All_MoHs_Merge_113th_FS_CM.drop(columns = list)

All_MoHs_Merge_113th_FS_CM.head()
# Out:
#    person                                      name  VoteAlong113thRatio_FS_CM
# 0  400008  Rep. Robert “Rob” Andrews [D, 1990-2014]                        NaN
# 1  400021        Rep. Xavier Becerra [D, 2013-2017]                   0.571429
# 2  400030    Rep. Sanford Bishop Jr. [D, 1993-2022]                   0.714286
# 3  400031        Rep. Timothy Bishop [D, 2003-2014]                   0.714286
# 4  400033       Rep. Earl Blumenauer [D, 1996-2022]                   0.571429

# %%
# 114th Session


df1 = my_function("114th/congress_votes_114-2015_h8.csv", "1")
a1 = df1[["person", "name"]] 
b1 = df1.drop(columns = ["state", "district", "vote",  "name", "party"])


df2 = my_function("114th/congress_votes_114-2015_h9.csv", "2")
a2 = df2[["person", "name"]] 
b2 = df2.drop(columns = ["state", "district", "vote",  "name", "party"])


df3 = my_function("114th/congress_votes_114-2015_h309.csv", "3")
a3 = df3[["person", "name"]] 
b3 = df3.drop(columns = ["state", "district", "vote",  "name", "party"])


df4 = my_function("114th/congress_votes_114-2015_h705.csv", "4")
a4= df4[["person", "name"]] 
b4 = df4.drop(columns = ["state", "district", "vote",  "name", "party"])


df5 = my_function("114th/congress_votes_114-2016_h250.csv", "5")
a5 = df5[["person", "name"]] 
b5 = df5.drop(columns = ["state", "district", "vote",  "name", "party"])


List_MoHs = a1.append(a2.append(a3.append(a4.append(a5))))
#List_MoHs = a1.append(a2.append(a3.append(a4.append(a5.append(a6.append(a7))))))

Unique_MoHs = Unique_MoHs_function(List_MoHs)



All_MoHs_Merge = pd.merge(Unique_MoHs , b1, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b2, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b3, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b4, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b5, how='left')
#All_MoHs_Merge = pd.merge(All_MoHs_Merge , b6, how='left')
#All_MoHs_Merge = pd.merge(All_MoHs_Merge , b7, how='left')


All_MoHs_Merge["VoteAlong114thRatio_FS_CM"] = All_MoHs_Merge["VoteAlong1"] + All_MoHs_Merge["VoteAlong2"] + All_MoHs_Merge["VoteAlong3"]+ All_MoHs_Merge["VoteAlong4"]+ All_MoHs_Merge["VoteAlong5"] 
All_MoHs_Merge["VoteAlong114thRatio_FS_CM"] = All_MoHs_Merge["VoteAlong114thRatio_FS_CM"]/5

All_MoHs_Merge_114th_FS_CM = All_MoHs_Merge

list = ["VoteAlong1", "VoteAlong2", "VoteAlong3", "VoteAlong4", "VoteAlong5"] 
All_MoHs_Merge_114th_FS_CM =  All_MoHs_Merge_114th_FS_CM.drop(columns = list)


All_MoHs_Merge_114th_FS_CM.head()
# Out:
#    person                                    name  VoteAlong114thRatio_FS_CM
# 0  400021      Rep. Xavier Becerra [D, 2013-2017]                        0.2
# 1  400030  Rep. Sanford Bishop Jr. [D, 1993-2022]                        0.8
# 2  400033     Rep. Earl Blumenauer [D, 1996-2022]                        0.4
# 3  400047        Rep. Robert Brady [D, 1998-2018]                        0.4
# 4  400048       Rep. Corrine Brown [D, 2013-2016]                        0.4

# %%
# 115th Session


df1 = my_function("115th/congress_votes_115-2017_h54.csv", "1")
a1 = df1[["person", "name"]] 
b1 = df1.drop(columns = ["state", "district", "vote",  "name", "party"])

df2 = my_function("115th/congress_votes_115-2017_h299.csv", "2")
a2 = df2[["person", "name"]] 
b2 = df2.drop(columns = ["state", "district", "vote",  "name", "party"])

df3 = my_function("115th/congress_votes_115-2017_h528.csv", "3")
a3 = df3[["person", "name"]] 
b3 = df3.drop(columns = ["state", "district", "vote",  "name", "party"])

df4 = my_function("115th/congress_votes_115-2017_h699.csv", "4")
a4 = df4[["person", "name"]] 
b4 = df4.drop(columns = ["state", "district", "vote",  "name", "party"])

#df5 = my_function("115th/congress_votes_115-2018_h434.csv", "5")
#a5 = df5[["person", "name"]] 
#b5 = df5.drop(columns = ["state", "district", "vote",  "name", "party"])


List_MoHs = a1.append(a2.append(a3.append(a4)))
#List_MoHs = a1.append(a2.append(a3.append(a4.append(a5.append(a6.append(a7))))))
Unique_MoHs = Unique_MoHs_function(List_MoHs)


All_MoHs_Merge = pd.merge(Unique_MoHs , b1, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b2, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b3, how='left')
All_MoHs_Merge = pd.merge(All_MoHs_Merge , b4, how='left')
#All_MoHs_Merge = pd.merge(All_MoHs_Merge , b5, how='left')


All_MoHs_Merge["VoteAlong115thRatio_FS_CM"] = All_MoHs_Merge["VoteAlong1"] + All_MoHs_Merge["VoteAlong2"] + All_MoHs_Merge["VoteAlong3"]  + All_MoHs_Merge["VoteAlong4"]  
All_MoHs_Merge["VoteAlong115thRatio_FS_CM"] = All_MoHs_Merge["VoteAlong115thRatio_FS_CM"]/4

All_MoHs_Merge_115th_FS_CM = All_MoHs_Merge


list = ["VoteAlong1","VoteAlong2","VoteAlong3","VoteAlong4"]
All_MoHs_Merge_115th_FS_CM =  All_MoHs_Merge_115th_FS_CM.drop(columns = list)


All_MoHs_Merge_115th_FS_CM.head()
# Out:
#    person                                    name  VoteAlong115thRatio_FS_CM
# 0  400021      Rep. Xavier Becerra [D, 2013-2017]                        NaN
# 1  400030  Rep. Sanford Bishop Jr. [D, 1993-2022]                       0.25
# 2  400033     Rep. Earl Blumenauer [D, 1996-2022]                       0.00
# 3  400047        Rep. Robert Brady [D, 1998-2018]                       0.00
# 4  400063     Rep. Michael Capuano [D, 2013-2018]                       0.00

# %%
# 116th Session

# No Roll-Call Votes in this section

# %%
# Merge different sessions into one data set 

c1 = All_MoHs_Merge_113th_FS_CM[["person", "name"]] 
c2 = All_MoHs_Merge_114th_FS_CM[["person", "name"]] 
c3 = All_MoHs_Merge_115th_FS_CM[["person", "name"]] 

    
List_MoHs_All_Sessions = c1.append(c2.append(c3))

List_MoHs_All_Sessions = List_MoHs_All_Sessions.drop_duplicates()
List_MoHs_All_Sessions = pd.DataFrame(List_MoHs_All_Sessions)
List_MoHs_All_Sessions.columns = ['person', 'name']
Unique_MoHs_All_Sessions = List_MoHs_All_Sessions


MoHs_VoteRatios_113_116 = pd.merge(Unique_MoHs_All_Sessions , All_MoHs_Merge_113th_FS_CM, how='left')
MoHs_VoteRatios_113_116 = pd.merge(MoHs_VoteRatios_113_116 , All_MoHs_Merge_114th_FS_CM, how='left')
MoHs_VoteRatios_113_116 = pd.merge(MoHs_VoteRatios_113_116 , All_MoHs_Merge_115th_FS_CM, how='left')

MoHs_VoteRatios_113_116['VoteAlong116thRatio_FS_CM'] = 1

MoHs_VoteRatios_113_116.head()

MoHs_VoteRatios_113_116_FS_CM = MoHs_VoteRatios_113_116

# %%
MoHs_VoteRatios_113_116_FS_CM.head()
# Out:
#    person                                      name  \
# 0  400008  Rep. Robert “Rob” Andrews [D, 1990-2014]
# 1  400021        Rep. Xavier Becerra [D, 2013-2017]
# 2  400030    Rep. Sanford Bishop Jr. [D, 1993-2022]
# 3  400031        Rep. Timothy Bishop [D, 2003-2014]
# 4  400033       Rep. Earl Blumenauer [D, 1996-2022]
#
#    VoteAlong113thRatio_FS_CM  VoteAlong114thRatio_FS_CM  \
# 0                        NaN                        NaN
# 1                   0.571429                        0.2
# 2                   0.714286                        0.8
# 3                   0.714286                        NaN
# 4                   0.571429                        0.4
#
#    VoteAlong115thRatio_FS_CM  VoteAlong116thRatio_FS_CM
# 0                        NaN                          1
# 1                        NaN                          1
# 2                       0.25                          1
# 3                        NaN                          1
# 4                       0.00                          1

# %%
# Export Dataframe into CSV

compression_opts = dict(method='zip',
                        archive_name='MoHs_VoteRatios_113_116_FS_CM.csv')  
MoHs_VoteRatios_113_116_FS_CM.to_csv('MoHs_VoteRatios_113_116_FS_CM.zip', index=False,
          compression=compression_opts)

# %%
#-------------------------------------------------------------
#------------- Ideenspeicher --------------------------------
#------------------------------------------------------------

list_of_bills_113 = ["congress_votes_113-2013_h215.csv", "congress_votes_113-2013_h216.csv", "congress_votes_113-2013_h218.csv"]
list_of_bills_114 = ["VoteAlong2013_h215", "VoteAlong2013_h215", "VoteAlong2013_h215"]
list_of_bills_115 = ["VoteAlong2013_h215", "VoteAlong2013_h215", "VoteAlong2013_h215"]
list_of_bills_116 = ["VoteAlong2013_h215", "VoteAlong2013_h215", "VoteAlong2013_h215"]


#--------------

session = "113th/"

number_of_bills = 3

for x in range(number_of_bills): 
    link = session + list_of_bills_113[x]
    bill = list_of_bills_113[x] 
    df = my_function(link, bill)
    a = df[["person", "name"]] 
    b = df.drop(columns = ["state", "district", "vote",  "name", "party"])
    List_MoHs = a.append(a)
    

Unique_MoHs = Unique_MoHs_function(List_MoHs)


for x in range(number_of_bills): 
    link = session + list_of_bills_113[x]
    bill = list_of_bills_113[x] 
    df = my_function(link, bill)
    b = df.drop(columns = ["state", "district", "vote",  "name", "party"])
    Unique_MoHs = pd.merge(Unique_MoHs , b, how='left')
    

All_MoHs_Merge = Unique_MoHs
